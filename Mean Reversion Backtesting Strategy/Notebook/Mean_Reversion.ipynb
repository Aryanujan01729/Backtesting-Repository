# %%
import os,sys
sys.path.append(os.path.abspath(".."))
from src.data_loader import get_data
from src.Strategy import Mean_Reversion_strategy
from src.BackTesting import run_backtest
from src.Performance import compute_performance
from src.Graph import plot_equity

# %%
price = get_data("QQQ",start="2015-01-01")
df= Mean_Reversion_strategy(price,30)
df1,perf=run_backtest(df)
print(df['position'].value_counts())

print(perf)
plot_equity(df1)
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# position
#  1.0    1779
# -1.0     744
#  0.0     158
# Name: count, dtype: int64
# {'Total_return': 0.3180717653487677, 'CAGR': 0.0263083247405691, 'Voltality': 0.2160315961938197, 'Sharpe': 0.2284065086277224, 'Max Drawdown': -0.4378633831218474}
# C:\Users\USER\Mean Reversion Backtesting\src\data_loader.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data=pd.read_csv(path,index_col=0,parse_dates=True)
